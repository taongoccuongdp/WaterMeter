# %%
import json
dict = {'10': 'A', '11': 'B', '12': 'C', '13': 'D', '14': 'E', '15': 'F', '16': 'G', '17': 'H', '18': 'I', '19': 'J'}
json_dir = r"Dataset/easy_samples.json"
dataset = json.load(open(json_dir))
imgs = list(dataset.keys())
replace = ""
for img in imgs:
    value = dataset[img]
    str = value.split(',')
    temp = []
    for s in str:
        for d in dict.keys():
            if s == d:
                replace = dict[d]
        if replace == "":
            temp.append(s)
        else:
            temp.append(replace)
        replace = ""
    rs = ','.join(temp)
    dataset[img] = rs
with open(r"Dataset/easy_samples.json", "w", encoding='utf-8') as output:
    json.dump(dataset, output, ensure_ascii=False, indent=4)

# %%
import numpy as np
import cv2
    img = cv2.imread('Dataset/easy_samples/10.png',0)
    # create a CLAHE object (Arguments are optional).
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    cl1 = clahe.apply(img) 
    cv2.imwrite('test_10.png',cl1)
# Out:
#   File "<ipython-input-8-a60bce7d8d13>", line 3
#     img = cv2.imread('Dataset/easy_samples/10.png',0)
#     ^
# IndentationError: unexpected indent

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('test_10.png',0)
# global thresholding
ret1,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
ret3,th3 = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import json
dict = {'10': 'A', '11': 'B', '12': 'C', '13': 'D', '14': 'E', '15': 'F', '16': 'G', '17': 'H', '18': 'I', '19': 'J'}
json_dir = r"Dataset/easy_samples.json"
dataset = json.load(open(json_dir))
imgs = list(dataset.keys())
replace = ""
for img in imgs:
    value = dataset[img]
    str = value.split(',')
    rs = "".join(str)
    dataset[img] = rs
with open(r"Dataset/easy_samples.json", "w", encoding='utf-8') as output:
    json.dump(dataset, output, ensure_ascii=False, indent=4)
